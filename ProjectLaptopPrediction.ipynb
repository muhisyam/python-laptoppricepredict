# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df['Ram'] = df['Ram'].str.replace('GB','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df['Ram'] = df['Ram'].astype('int32')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.info
# Out:
# <bound method DataFrame.info of      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz    8            128GB SSD
# 1                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3                     Intel Core i7 2.7GHz   16            512GB SSD
# 4                     Intel Core i5 3.1GHz    8            256GB SSD
# ...                                    ...  ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz    4            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz   16            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz    2   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz    6              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 11 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), int32(1), object(8)
# memory usage: 107.0+ KB

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x=df['Company'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: ScreenResolution, dtype: int64

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df['IPS'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080            0    1

# %%
new_res = df['ScreenResolution'].str.split('x', n=1, expand=True)

# %%
df['X_Res'] = new_res[0]
df['Y_Res'] = new_res[1]

# %%
df.sample(5)
# Out:
#     Company  TypeName  Inches             ScreenResolution  \
# 435    Asus    Gaming    17.3            Full HD 1920x1080
# 974    Asus    Gaming    17.3            Full HD 1920x1080
# 126      HP  Notebook    14.0            Full HD 1920x1080
# 644    Acer  Notebook    15.6                     1366x768
# 658  Lenovo    Gaming    15.6  IPS Panel Full HD 1920x1080
#
#                              Cpu  Ram                Memory  \
# 435        AMD Ryzen 1600 3.2GHz    8  256GB SSD +  1TB HDD
# 974  Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 126   Intel Core i5 8250U 1.6GHz    8               1TB HDD
# 644     Intel Core i3 6006U 2GHz    4             500GB HDD
# 658  Intel Core i7 6700HQ 2.6GHz    8  128GB SSD +  1TB HDD
#
#                          Gpu       OpSys  Weight       Price  Touchscreen  \
# 435        AMD Radeon RX 580  Windows 10   3.2kg   90309.600            0
# 974  Nvidia GeForce GTX 1060  Windows 10  2.73kg  109218.672            0
# 126   Intel UHD Graphics 620  Windows 10  1.63kg   43263.360            0
# 644    Intel HD Graphics 520  Windows 10   2.4kg   23976.000            0
# 658   Nvidia GeForce GTX 960  Windows 10  3.31kg   63722.880            0
#
#      IPS                   X_Res Y_Res
# 435    0            Full HD 1920  1080
# 974    0            Full HD 1920  1080
# 126    0            Full HD 1920  1080
# 644    0                    1366   768
# 658    1  IPS Panel Full HD 1920  1080

# %%
df['X_Res'] = df['X_Res'].str.replace(',', '').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080            0    1
#
#   X_Res Y_Res
# 0  2560  1600
# 1  1440   900
# 2  1920  1080
# 3  2880  1800
# 4  2560  1600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_Res             1303 non-null   object
#  14  Y_Res             1303 non-null   object
# dtypes: float64(2), int32(1), int64(2), object(10)
# memory usage: 147.7+ KB

# %%
df['X_Res'] = df['X_Res'].astype('int')
df['Y_Res'] = df['Y_Res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_Res             1303 non-null   int32
#  14  Y_Res             1303 non-null   int32
# dtypes: float64(2), int32(3), int64(2), object(8)
# memory usage: 137.6+ KB

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_Res          0.556529
# Y_Res          0.552809
# Name: Price, dtype: float64

# %%
df['PPI'] = (((df['X_Res']**2) + (df['Y_Res']**2))**0.5/df['Inches']).astype('float')

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_Res          0.556529
# Y_Res          0.552809
# PPI            0.473487
# Name: Price, dtype: float64

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080            0    1
#
#    X_Res  Y_Res         PPI
# 0   2560   1600  226.983005
# 1   1440    900  127.677940
# 2   1920   1080  141.211998
# 3   2880   1800  220.534624
# 4   2560   1600  226.983005

# %%
df.drop(columns = ['ScreenResolution'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#          Price  Touchscreen  IPS  X_Res  Y_Res         PPI
# 0   71378.6832            0    1   2560   1600  226.983005
# 1   47895.5232            0    0   1440    900  127.677940
# 2   30636.0000            0    0   1920   1080  141.211998
# 3  135195.3360            0    1   2880   1800  220.534624
# 4   96095.8080            0    1   2560   1600  226.983005

# %%
df['CpuName'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#          Price  Touchscreen  IPS  X_Res  Y_Res         PPI        CpuName
# 0   71378.6832            0    1   2560   1600  226.983005  Intel Core i5
# 1   47895.5232            0    0   1440    900  127.677940  Intel Core i5
# 2   30636.0000            0    0   1920   1080  141.211998  Intel Core i5
# 3  135195.3360            0    1   2880   1800  220.534624  Intel Core i7
# 4   96095.8080            0    1   2560   1600  226.983005  Intel Core i5

# %%
def processor(name):
    if name == 'Intel Core i7' or name == 'Intel Core i5' or name == 'Intel Core i3':
        return name
    else:
        if name.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['CpuBrand'] = df['CpuName'].apply(processor)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#          Price  Touchscreen  IPS  X_Res  Y_Res         PPI        CpuName  \
# 0   71378.6832            0    1   2560   1600  226.983005  Intel Core i5
# 1   47895.5232            0    0   1440    900  127.677940  Intel Core i5
# 2   30636.0000            0    0   1920   1080  141.211998  Intel Core i5
# 3  135195.3360            0    1   2880   1800  220.534624  Intel Core i7
# 4   96095.8080            0    1   2560   1600  226.983005  Intel Core i5
#
#         CpuBrand
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# 3  Intel Core i7
# 4  Intel Core i5

# %%
df['CpuBrand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['CpuBrand'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['CpuName'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#          Price  Touchscreen  IPS  X_Res  Y_Res         PPI       CpuBrand
# 0   71378.6832            0    1   2560   1600  226.983005  Intel Core i5
# 1   47895.5232            0    0   1440    900  127.677940  Intel Core i5
# 2   30636.0000            0    0   1920   1080  141.211998  Intel Core i5
# 3  135195.3360            0    1   2880   1800  220.534624  Intel Core i7
# 4   96095.8080            0    1   2560   1600  226.983005  Intel Core i5

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Ram', ylabel='Price'>

# %%
df['Memory'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer2HDD', 'Layer2SSD'],inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10432\2579333588.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10432\2579333588.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.drop(columns=['Memory'],inplace=True)
df.sample(5)
# Out:
#      Company            TypeName  Inches                          Cpu  Ram  \
# 727     Dell  2 in 1 Convertible    13.3   Intel Core i3 7100U 2.4GHz    4
# 912   Lenovo            Notebook    15.6   Intel Core i7 7500U 2.7GHz    6
# 45     Apple           Ultrabook    13.3         Intel Core i5 2.0GHz    8
# 428       HP              Gaming    17.3  Intel Core i7 7700HQ 2.8GHz   12
# 874  Samsung           Ultrabook    15.0   Intel Core i7 7500U 2.7GHz   16
#
#                          Gpu       OpSys  Weight      Price  Touchscreen  IPS  \
# 727    Intel HD Graphics 620  Windows 10  1.71kg   34578.72            1    0
# 912     Nvidia GeForce 940MX  Windows 10   2.2kg   42037.92            0    0
# 45   Intel Iris Graphics 540       macOS  1.37kg   75604.32            0    1
# 428  Nvidia GeForce GTX 1070  Windows 10  3.35kg  106506.72            0    0
# 874     Nvidia GeForce 940MX  Windows 10  1.23kg   98514.72            0    0
#
#      X_Res  Y_Res         PPI       CpuBrand   HDD  SSD
# 727   1920   1080  165.632118  Intel Core i3  1000    0
# 912   1920   1080  141.211998  Intel Core i7     0  256
# 45    2560   1600  226.983005  Intel Core i5     0  256
# 428   1920   1080  127.335675  Intel Core i7  1000  256
# 874   1920   1080  146.860478  Intel Core i7     0  256

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_Res          0.556529
# Y_Res          0.552809
# PPI            0.473487
# HDD           -0.096441
# SSD            0.670799
# Name: Price, dtype: float64

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['GpuBrand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['GpuBrand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: GpuBrand, dtype: int64

# %%
df = df[df['GpuBrand'] != 'ARM']

# %%
df['GpuBrand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: GpuBrand, dtype: int64

# %%
sns.barplot(x=df['GpuBrand'],y=df['Price'],estimator=np.median)
# Out:
# <AxesSubplot:xlabel='GpuBrand', ylabel='Price'>

# %%
df.drop(columns=['Gpu'],inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10432\1111925144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  OpSys  Weight  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8  macOS  1.37kg
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8  macOS  1.34kg
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8  No OS  1.86kg
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16  macOS  1.83kg
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8  macOS  1.37kg
#
#          Price  Touchscreen  IPS  X_Res  Y_Res         PPI       CpuBrand  \
# 0   71378.6832            0    1   2560   1600  226.983005  Intel Core i5
# 1   47895.5232            0    0   1440    900  127.677940  Intel Core i5
# 2   30636.0000            0    0   1920   1080  141.211998  Intel Core i5
# 3  135195.3360            0    1   2880   1800  220.534624  Intel Core i7
# 4   96095.8080            0    1   2560   1600  226.983005  Intel Core i5
#
#    HDD  SSD GpuBrand
# 0    0  128    Intel
# 1    0    0    Intel
# 2    0  256    Intel
# 3    0  512      AMD
# 4    0  256    Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def os_name(name):
    if name == 'Windows 10' or name == 'Windows 7' or name == 'Windows 10 S':
        return 'Windows'
    elif name == 'macOS' or name == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['OpSysName'] = df['OpSys'].apply(os_name)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10432\825518623.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OpSysName'] = df['OpSys'].apply(os_name)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  OpSys  Weight  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8  macOS  1.37kg
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8  macOS  1.34kg
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8  No OS  1.86kg
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16  macOS  1.83kg
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8  macOS  1.37kg
#
#          Price  Touchscreen  IPS  X_Res  Y_Res         PPI       CpuBrand  \
# 0   71378.6832            0    1   2560   1600  226.983005  Intel Core i5
# 1   47895.5232            0    0   1440    900  127.677940  Intel Core i5
# 2   30636.0000            0    0   1920   1080  141.211998  Intel Core i5
# 3  135195.3360            0    1   2880   1800  220.534624  Intel Core i7
# 4   96095.8080            0    1   2560   1600  226.983005  Intel Core i5
#
#    HDD  SSD GpuBrand           OpSysName
# 0    0  128    Intel                 Mac
# 1    0    0    Intel                 Mac
# 2    0  256    Intel  Others/No OS/Linux
# 3    0  512      AMD                 Mac
# 4    0  256    Intel                 Mac

# %%
df.drop(columns=['OpSys', 'Weight', 'Inches'],inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10432\2015260178.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys', 'Weight', 'Inches'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram        Price  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8   71378.6832
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8   47895.5232
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8   30636.0000
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16  135195.3360
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8   96095.8080
#
#    Touchscreen  IPS  X_Res  Y_Res         PPI       CpuBrand  HDD  SSD  \
# 0            0    1   2560   1600  226.983005  Intel Core i5    0  128
# 1            0    0   1440    900  127.677940  Intel Core i5    0    0
# 2            0    0   1920   1080  141.211998  Intel Core i5    0  256
# 3            0    1   2880   1800  220.534624  Intel Core i7    0  512
# 4            0    1   2560   1600  226.983005  Intel Core i5    0  256
#
#   GpuBrand           OpSysName
# 0    Intel                 Mac
# 1    Intel                 Mac
# 2    Intel  Others/No OS/Linux
# 3      AMD                 Mac
# 4    Intel                 Mac

# %%
df.corr()['Price']
# Out:
# Ram            0.742905
# Price          1.000000
# Touchscreen    0.192917
# IPS            0.253320
# X_Res          0.557369
# Y_Res          0.554591
# PPI            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
#       Touchscreen  IPS  X_Res  Y_Res         PPI               CpuBrand   HDD  \
# 0               0    1   2560   1600  226.983005          Intel Core i5     0
# 1               0    0   1440    900  127.677940          Intel Core i5     0
# 2               0    0   1920   1080  141.211998          Intel Core i5     0
# 3               0    1   2880   1800  220.534624          Intel Core i7     0
# 4               0    1   2560   1600  226.983005          Intel Core i5     0
# ...           ...  ...    ...    ...         ...                    ...   ...
# 1298            1    1   1920   1080  157.350512          Intel Core i7     0
# 1299            1    1   3200   1800  276.053530          Intel Core i7     0
# 1300            0    0   1366    768  111.935204  Other Intel Processor     0
# 1301            0    0   1366    768  100.454670          Intel Core i7  1000
# 1302            0    0   1366    768  100.454670  Other Intel Processor   500
#
#       SSD GpuBrand           OpSysName
# 0     128    Intel                 Mac
# 1       0    Intel                 Mac
# 2     256    Intel  Others/No OS/Linux
# 3     512      AMD                 Mac
# 4     256    Intel                 Mac
# ...   ...      ...                 ...
# 1298  128    Intel             Windows
# 1299  512    Intel             Windows
# 1300    0    Intel             Windows
# 1301    0      AMD             Windows
# 1302    0    Intel             Windows
#
# [1302 rows x 14 columns]

# %%
df.drop(columns=['Cpu', 'X_Res', 'Y_Res'],inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10432\719826378.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Cpu', 'X_Res', 'Y_Res'],inplace=True)

# %%
X = df.drop(columns=['Price'])
Y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Touchscreen  IPS         PPI  \
# 0      Apple           Ultrabook    8            0    1  226.983005
# 1      Apple           Ultrabook    8            0    0  127.677940
# 2         HP            Notebook    8            0    0  141.211998
# 3      Apple           Ultrabook   16            0    1  220.534624
# 4      Apple           Ultrabook    8            0    1  226.983005
# ...      ...                 ...  ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16            1    1  276.053530
# 1300  Lenovo            Notebook    2            0    0  111.935204
# 1301      HP            Notebook    6            0    0  100.454670
# 1302    Asus            Notebook    4            0    0  100.454670
#
#                    CpuBrand   HDD  SSD GpuBrand           OpSysName
# 0             Intel Core i5     0  128    Intel                 Mac
# 1             Intel Core i5     0    0    Intel                 Mac
# 2             Intel Core i5     0  256    Intel  Others/No OS/Linux
# 3             Intel Core i7     0  512      AMD                 Mac
# 4             Intel Core i5     0  256    Intel                 Mac
# ...                     ...   ...  ...      ...                 ...
# 1298          Intel Core i7     0  128    Intel             Windows
# 1299          Intel Core i7     0  512    Intel             Windows
# 1300  Other Intel Processor     0    0    Intel             Windows
# 1301          Intel Core i7  1000    0      AMD             Windows
# 1302  Other Intel Processor   500    0    Intel             Windows
#
# [1302 rows x 11 columns]

# %%
Y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Touchscreen  IPS         PPI  \
# 183   Toshiba            Notebook    8            0    0  100.454670
# 1141      MSI              Gaming    8            0    0  141.211998
# 1049     Asus             Netbook    4            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4            1    1  141.211998
# 878      Dell            Notebook    4            0    0  141.211998
# ...       ...                 ...  ...          ...  ...         ...
# 466      Acer            Notebook    4            0    0  100.454670
# 299      Asus           Ultrabook   16            0    0  141.211998
# 493      Acer            Notebook    8            0    0  100.454670
# 527    Lenovo            Notebook    8            0    0  100.454670
# 1193    Apple           Ultrabook    8            0    1  226.415547
#
#                    CpuBrand   HDD  SSD GpuBrand           OpSysName
# 183           Intel Core i5     0  128    Intel             Windows
# 1141          Intel Core i7  1000  128   Nvidia             Windows
# 1049  Other Intel Processor     0    0    Intel  Others/No OS/Linux
# 1020          Intel Core i3  1000    0    Intel             Windows
# 878           Intel Core i5  1000  128   Nvidia             Windows
# ...                     ...   ...  ...      ...                 ...
# 466           Intel Core i3   500    0   Nvidia             Windows
# 299           Intel Core i7     0  512   Nvidia             Windows
# 493           AMD Processor  1000    0      AMD             Windows
# 527           Intel Core i3  2000    0   Nvidia  Others/No OS/Linux
# 1193  Other Intel Processor     0    0    Intel                 Mac
#
# [1106 rows x 11 columns]

# %%
y_train
# Out:
# 183     10.651384
# 1141    11.016798
# 1049     9.638174
# 1020    10.655148
# 878     10.791749
#           ...
# 466     10.126164
# 299     11.267217
# 493     10.336864
# 527     10.104611
# 1193    11.034319
# Name: Price, Length: 1106, dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error,accuracy_score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram       Price  Touchscreen  IPS         PPI  \
# 0   Apple  Ultrabook    8  71378.6832            0    1  226.983005
#
#         CpuBrand  HDD  SSD GpuBrand OpSysName
# 0  Intel Core i5    0  128    Intel       Mac

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,6,9,10])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8093011933941263
# MAE 0.2068367321945198

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,6,9,10])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8794911978461283
# MAE 0.16797367912519917

# %%
# import pickle

# pickle.dump(df,open('df.pkl','wb'))
# pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
# df
